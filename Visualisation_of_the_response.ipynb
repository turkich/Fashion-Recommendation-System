# %% [markdown]
# ##this notebook take the output of the module3_4 and visualize the results

# %%
response={'took': 990,
 'timed_out': False,
 '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
 'hits': {'total': {'value': 90, 'relation': 'eq'},
  'max_score': 1.1066078,
  'hits': [{'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '34',
    '_score': 1.1066078,
    '_source': {'file_name': '40993c2c77.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1e2mRo7tSxrm924H0aFPfas1u8bib4Mz-fQ&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '10',
    '_score': 1.1048263,
    '_source': {'file_name': 'a996078e33.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR5XfS2u_NMyqGm4-T3MDRwvkC6Rs2KuB1gYA&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '100',
    '_score': 1.1030462,
    '_source': {'file_name': '80397cb449.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRs_9tS0PA8__kLo9HOzflxtwKOOXZPa7hLjA&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '33',
    '_score': 1.102497,
    '_source': {'file_name': '07890ecc9e.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSJmlTT55eYTRkI0BeFsYTN6RQg_kaTK9qviQ&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '124',
    '_score': 1.1021621,
    '_source': {'file_name': '30afff0fdf.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT1u63lxBeLBnhf55B6tDvUUAoAfBzuPnWsTA&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '25',
    '_score': 1.101595,
    '_source': {'file_name': 'd0fd9f83dc.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTRS1lWuA7mT0OWY9JFt88tRaRliFvL88DQDA&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '113',
    '_score': 1.1011555,
    '_source': {'file_name': 'b6cc57df5f.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRLmRFZGpcyd_SoTnbKGupHqkJqPITV41BmuQ&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '126',
    '_score': 1.1004806,
    '_source': {'file_name': '21cfddd670.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSRacbJgisdxUYYBwucwjjNBTItsbYMveUANA&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '19',
    '_score': 1.1004288,
    '_source': {'file_name': 'f29931e7cf.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcToZ6Q8lm6Ko-q8P_H-rWaMP0vr7tllGFHBKA&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '26',
    '_score': 1.0999875,
    '_source': {'file_name': '36b5bca557.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSjS-q1rKX2kKnB7lvIem5S1rWj2tr5J3unBQ&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '111',
    '_score': 1.0995305,
    '_source': {'file_name': '6d6d203715.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ2kpq0OgnlRvQ9JdBYifE_0LutgeIfMr9vpA&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '104',
    '_score': 1.099512,
    '_source': {'file_name': '51574e0133.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS7P9waUjN0W4wWcfZm2K9AQuwfnbV-acKEDw&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '96',
    '_score': 1.0993993,
    '_source': {'file_name': '5cb8359588.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRjA88QKbRoy-MbrqJT3Vqp-Bv0VbjHVZAf9A&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '94',
    '_score': 1.0992721,
    '_source': {'file_name': '9b16c3700d.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQDYo3ou0F1UMol-ME8F2vHat9woX8qz1mdZg&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '6',
    '_score': 1.0987769,
    '_source': {'file_name': '931974ff91.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQARrsQeQTozvi0Grrpk14OXzrO_hByjICFhA&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '102',
    '_score': 1.0984693,
    '_source': {'file_name': 'b80da58a0f.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcScixmWslbSsBHWO6zI5x3XJU5Co90QDmhONw&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '115',
    '_score': 1.0981976,
    '_source': {'file_name': '5e1f92619b.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcST5CogvfXPlHq3ZqSElIW08pHi9kEGbqsugA&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '125',
    '_score': 1.0965918,
    '_source': {'file_name': 'e65143b9c7.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSVc_x5QAT4Wt4iYoUcLcJ8_1PBr7cVELMQig&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '3',
    '_score': 1.09594,
    '_source': {'file_name': 'e1a598912c.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTV3UUE_l4pg-ZUe24TvDqRJ61x50FTOeJG-Q&usqp=CAU'}},
   {'_index': 'upper_ware',
    '_type': '_doc',
    '_id': '32',
    '_score': 1.0953034,
    '_source': {'file_name': 'f52be09f72.jpg',
     'url': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT4w9oh36J2tyv0Je3JwT7UrBe95Kmlo3paxg&usqp=CAU'}}]}}

# %% [markdown]
# ### Analyse du résulat obtenu

# %%
nbr=len(response['hits']['hits'])
print(f'le nombre de produits similaires trouvé est {nbr}')
# Out:
# le nombre de produits similaires trouvé est 20

# %%
import pandas as pd 
data=pd.read_csv('/content/drive/MyDrive/buy_me_that_look/data/data.csv')
data.loc[32,'file_name']+'jpg'
# Out:
# 'f52be09f72.jpg'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **=> Donc l'id retourné est égale de l'id de l'image dans le dataframe**

# %%
import pandas as pd 
data=pd.read_csv('/content/drive/MyDrive/buy_me_that_look/data/data.csv')
data
# Out:
#       id   super_cat                cat             info    file_name  \
# 0      0  upper_ware       men_t-shirts  abdee3a327.json  abdee3a327.
# 1      1  upper_ware       men_t-shirts  9bef3d2e8c.json  9bef3d2e8c.
# 2      2  upper_ware       men_t-shirts  ac83465fdd.json  ac83465fdd.
# 3      3  upper_ware       men_t-shirts  e1a598912c.json  e1a598912c.
# 4      4  upper_ware       men_t-shirts  baffb59de9.json  baffb59de9.
# ..   ...         ...                ...              ...          ...
# 165  165  lower_ware  men_casual_shorts  f2c8beaf29.json  f2c8beaf29.
# 166  166  lower_ware  men_casual_shorts  6ffcfd0660.json  6ffcfd0660.
# 167  167  lower_ware  men_casual_shorts  4319ce42c4.json  4319ce42c4.
# 168  168  lower_ware  men_casual_shorts  68ad4a2031.json  68ad4a2031.
# 169  169  lower_ware  men_casual_shorts  b018c6acda.json  b018c6acda.
#
#                                                    url
# 0    https://encrypted-tbn0.gstatic.com/images?q=tb...
# ...

# %%
import wget,cv2
filename = wget.download('https://www.myntra.com/tops/promod/promod-women-rust-brown-self-design-top/11722724/buy')
img = cv2.imread(filename,cv2.IMREAD_UNCHANGED)
#img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img

# %%
data.head(10)
# Out:
#    id   super_cat                cat             info    file_name  \
# 0   0  lower_ware  men_casual_shorts  008229aa76.json  008229aa76.
# 1   1  lower_ware  men_casual_shorts  00cd4462e6.json  00cd4462e6.
# 2   2  lower_ware  men_casual_shorts  06f9acd622.json  06f9acd622.
# 3   3  lower_ware  men_casual_shorts  1035a50e55.json  1035a50e55.
# 4   4  lower_ware  men_casual_shorts  1c5b145d69.json  1c5b145d69.
# 5   5  lower_ware  men_casual_shorts  2175ce9f15.json  2175ce9f15.
# 6   6  lower_ware  men_casual_shorts  3878fd8ef5.json  3878fd8ef5.
# 7   7  lower_ware  men_casual_shorts  38d1d97543.json  38d1d97543.
# 8   8  lower_ware  men_casual_shorts  3b896aa53c.json  3b896aa53c.
# 9   9  lower_ware  men_casual_shorts  4319ce42c4.json  4319ce42c4.
#
#                                                  url
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# ...

# %%
data['cat'][4]
# Out:
# 'men_casual_shorts'

# %%
df=data.copy()  
df
# Out:
#       id   super_cat                cat             info    file_name  \
# 0      0  upper_ware       men_t-shirts  abdee3a327.json  abdee3a327.
# 1      1  upper_ware       men_t-shirts  9bef3d2e8c.json  9bef3d2e8c.
# 2      2  upper_ware       men_t-shirts  ac83465fdd.json  ac83465fdd.
# 3      3  upper_ware       men_t-shirts  e1a598912c.json  e1a598912c.
# 4      4  upper_ware       men_t-shirts  baffb59de9.json  baffb59de9.
# ..   ...         ...                ...              ...          ...
# 165  165  lower_ware  men_casual_shorts  f2c8beaf29.json  f2c8beaf29.
# 166  166  lower_ware  men_casual_shorts  6ffcfd0660.json  6ffcfd0660.
# 167  167  lower_ware  men_casual_shorts  4319ce42c4.json  4319ce42c4.
# 168  168  lower_ware  men_casual_shorts  68ad4a2031.json  68ad4a2031.
# 169  169  lower_ware  men_casual_shorts  b018c6acda.json  b018c6acda.
#
#                                                    url
# 0    https://encrypted-tbn0.gstatic.com/images?q=tb...
# ...

# %% [markdown]
# test

# %%
import io
from PIL import Image
import requests
image_content = requests.get('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR5XfS2u_NMyqGm4-T3MDRwvkC6Rs2KuB1gYA&usqp=CAU').content
image_file = io.BytesIO(image_content)
image = Image.open(image_file).convert('RGB')
image
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F57E7461D90>

# %%
image = Image.open(image_file).convert('RGB')

# %%
def url_to_image(link):
    image_url = link
    #######
    #filename = wget.download(image_url)
    #filename='image.jpg'
    #urllib.request.urlretrieve(image_url, '/content/'+save_name)
    ######
    #img = cv2.imread(filename,cv2.IMREAD_UNCHANGED)
    #try:
    #img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    #except:
     # print("img=",img)
    image_content = requests.get(image_url).content
    image_file = io.BytesIO(image_content)
    #image = Image.open(image_file).convert('RGB')
    
    image=np.array(Image.open(image_file).convert('RGB'))
    #print(image)
    return image

# %%
list=[]
A=url_to_image('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1e2mRo7tSxrm924H0aFPfas1u8bib4Mz-fQ&usqp=CAU')
list.append(A)
#B=url_to_image('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSRacbJgisdxUYYBwucwjjNBTItsbYMveUANA&usqp=CAU')
#list.append(B)

# %%
list

# %%
def plot_images(li):
    fig, ax = plt.subplots(1,len(li), figsize=(20,20))
    if len(li)==1:
      outimage = li[0]
      auto_show = True
      height, width = outimage.shape[:2]
      ax.set_ylim(height + 10, -10)
      ax.set_xlim(-10, width + 10)
      ax.axis('off')
      img1 = outimage.astype(np.uint32).copy()
      ax.imshow(img1.astype(np.uint8))
      plt.show()
    else:

      for i in range(len(li)): 
        outimage = li[i]
        auto_show = True
        height, width = outimage.shape[:2]
        ax[i].set_ylim(height + 10, -10)
        ax[i].set_xlim(-10, width + 10)
        ax[i].axis('off')
        img1 = outimage.astype(np.uint32).copy()
        ax[i].imshow(img1.astype(np.uint8))
      plt.show()

# %%
plot_images(list)

# %%
A.shape[:2]
# Out:
# (243, 208)

# %% [markdown]
# ##Final function

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=43e3873e07c150a10cf9112d1271edc365128211cec837c2b4d1ea9e3f25a3f7
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...

# %%
import cv2, wget,json
import matplotlib.pyplot as plt
import io
from PIL import Image
import requests
import numpy as np
#import urllib.request
#utility finctions

def print_recommendations(response): #response in the output of the module3_4
  c=1
  flag = []
  li=[]
  def url_to_image(link):
    image_url = link
    image_content = requests.get(image_url).content
    image_file = io.BytesIO(image_content)
    #image = Image.open(image_file).convert('RGB')
    
    image=np.array(Image.open(image_file).convert('RGB'))
    #print(image)
    
    return image


  def get_image_links(n,df):
    id = int(n)
    root = '/content/drive/MyDrive/buy_me_that_look/data/Scrapped/'
    path = root + df['cat'][id] + '/' + df['info'][id]
    print(path)
    f = open(path)
    data = json.load(f)
    li.append(data['url']) #kenet data['links']
    f.close()
    return li


  def plot_images(li):
      fig, ax = plt.subplots(1,len(li), figsize=(4,4))
      if len(li)==1:
        outimage = li[0]
        auto_show = True
        height, width = outimage.shape[:2]
        ax.set_ylim(height + 10, -10)
        ax.set_xlim(-10, width + 10)
        ax.axis('off')
        img1 = outimage.astype(np.uint32).copy()
        ax.imshow(img1.astype(np.uint8))
        plt.show()
      else:

        for i in range(len(li)): 
          outimage = li[i]
          auto_show = True
          height, width = outimage.shape[:2]
          ax[i].set_ylim(height + 10, -10)
          ax[i].set_xlim(-10, width + 10)
          ax[i].axis('off')
          img1 = outimage.astype(np.uint32).copy()
          ax[i].imshow(img1.astype(np.uint8))
        plt.show()
  


  for i in response['hits']['hits']:
    url = i['_source']['url']
    id = i['_id']
    
    if url not in flag:
      
      flag.append(url)
      links = get_image_links(int(id),df)
      images = []
      for j in links:
        #print(j)
        #try:
        images=[] # hethi l zedtha ena tkhali ken l append le5rania
        #print('hhhhhh')
        img = url_to_image(j)
        images.append(img)
        #except:
        #  print('j=',j)
        #  print('links= ',links)
      #print(images)
      print(f"recomendation {c}")
      print("You can buy product from below link")
      print(url)
      print("="*200)
      plot_images(images)
      print('longueur de images= ',len(images))
      print("="*200)
      c+=1
      if c==6:
        break

# %%
print_recommendations(response)  ####
# Out:
# /content/drive/MyDrive/buy_me_that_look/data/Scrapped/men_t-shirts/40993c2c77.json
# recomendation 1
# You can buy product from below link
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1e2mRo7tSxrm924H0aFPfas1u8bib4Mz-fQ&usqp=CAU
# ...
# longueur de images=  1
# ...
# /content/drive/MyDrive/buy_me_that_look/data/Scrapped/men_t-shirts/a996078e33.json
# recomendation 2
# You can buy product from below link
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR5XfS2u_NMyqGm4-T3MDRwvkC6Rs2KuB1gYA&usqp=CAU
# ...
# longueur de images=  1
# ...
# /content/drive/MyDrive/buy_me_that_look/data/Scrapped/men_hoodie/80397cb449.json
# recomendation 3
# You can buy product from below link
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRs_9tS0PA8__kLo9HOzflxtwKOOXZPa7hLjA&usqp=CAU
# ...
# longueur de images=  1
# ...
# /content/drive/MyDrive/buy_me_that_look/data/Scrapped/men_t-shirts/07890ecc9e.json
# recomendation 4
# You can buy product from below link
# ...
